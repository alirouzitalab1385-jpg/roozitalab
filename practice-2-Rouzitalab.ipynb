# %%
main_students = {
        "first_name": "Ali",
        "last_name": "Rezaei",
        "student_code": "S12345",
        "date_of_birth": 1998,
        "age": 25,
        "desired_movie": "Inception",
        "desired_song": "Queen",
        "major": "Computer Engineering",
        "academic_level": "Msater",
        "entry_year": 2018,
        "gpa": 17.5,
        "favorite_courses": ["Algorithms", "Data Structures"],
        "hobbies": ["Reading", "Football"],
        "career_goal": "Software Developer",
        "strengths": ["Teamwork", "Problem-solving"],
        "weaknesses": ["Public speaking"],
        "favorite_book": "The Alchemist",
        "skills": ["Python", "C++"],
        "languages": ["English", "French"],
        "volunteer_experience": ["Teaching assistant"],
        "feedback": {
            "courses": "Challenging but rewarding",
            "professors": "Supportive and knowledgeable"
        }
}

# %%
student_1 = {
        "first_name": "Ali",
        "last_name": "Rouzitalab",
        "student_code": "4042023036",
        "date_of_birth": 2007,
        "desired_movie": "Inception",
        "major": "  electrical Engineering",
        "academic_level": "bachelors degree",
        "gpa": 0,
        "favorite_courses": ["Algorithms", "rizai"],
        "hobbies": ["Reading", "basketball"],
        "feedback": {
            "courses": "Challenging but rewarding",
            "professors": "Supportive and knowledgeable"
        }
}

# %%
new_dic=main_students|student_1
for i in new_dic:

 print(i,":",new_dic[i])
# Out:
# first_name : Ali
# last_name : Rouzitalab
# student_code : 4042023036
# date_of_birth : 2007
# age : 25
# desired_movie : Inception
# desired_song : Queen
# major :   electrical Engineering
# academic_level : bachelors degree
# entry_year : 2018
# gpa : 0
# favorite_courses : ['Algorithms', 'rizai']
# hobbies : ['Reading', 'basketball']
# career_goal : Software Developer
# strengths : ['Teamwork', 'Problem-solving']
# weaknesses : ['Public speaking']
# favorite_book : The Alchemist
# skills : ['Python', 'C++']
# languages : ['English', 'French']
# volunteer_experience : ['Teaching assistant']
# feedback : {'courses': 'Challenging but rewarding', 'professors': 'Supportive and knowledgeable'}

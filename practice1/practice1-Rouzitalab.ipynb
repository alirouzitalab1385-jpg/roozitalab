# %%
received_msg = "recived_msg.txt"
sent_msg = "sent_msg.txt"

# %%
with open(received_msg, "r", encoding = "utf-8") as file:
    file_content_a = file.read()
print(file_content_a)
# Out:
# You have a new website form submission:
# 1.	First Name
# Alex
# 2.	Email Address
# karen.ignaci5656@yahoo.com
# 3.	Phone Number
# 2386690554
# 4.	Message

# %%
name_1=file_content_a[54:58]

# %%
with open(sent_msg, "r", encoding = "utf-8") as file:
    file_content_b = file.read()
print(file_content_b)
# Out:
# Dear NAME, thank you for reaching out to our compony.
# We appreciate your interest and are excited to explore how we can support your needs.

# %%
index=file_content_b[5:9]

# %%
file_content_b.replace(index,name_1)
# Out:
# 'Dear Alex, thank you for reaching out to our compony.\nWe appreciate your interest and are excited to explore how we can support your needs.\n'
